# %%
import matplotlib.pyplot as plt
#plt.plot([10, 20, 30, 40])
#plt.plot([1, 2, 3, 4], [12, 43, 25, 15])
#plt.title('plotting')

#plt.title('legend')
#plt.plot([10, 20 ,30, 40], 'r.-.',  label='asc')
#plt.plot([40, 30, 20 ,10], 'k^--',  label = 'descend')
#plt.legend(loc=0)

#plt.hist([1,1,1,1,2,3,3,4,5,6,7,8,8,9,10], bins=15)

#import random
#result=[]

#for i in range(13):
#    result.append(random.randint(1, 1000))
#print(sorted(result))
#plt.boxplot(result)

#import numpy as np

#result = np.array(result)
#print("1/4: "+str(np.percentile(result,25)))
#print("2/4: "+str(np.percentile(result,50)))    
#print("3/4: "+str(np.percentile(result,75)))

#plt.style.use('classic')

#plt.bar([1,2,3,4,5,6],[1,2,3,4,5,6])

#plt.pie([500, 10,100,1000], labels=['A', 'B', 'AB', 'O'], colors=['skyblue','yellow','purple', 'lightgray'], autopct='%.2f%%', explode=(0.1,0.5,1,0))
#plt.title('A blood type')
#plt.legend(loc=5)

plt.scatter([1,3,5,7],[15,25,60,35], s=[30,90,270,810],c= range(4), cmap='jet', alpha=0.4)
plt.colorbar()
